# %%
dataset = 'FB15k'

# %%
from data.triple_set import TripleSet

extend_triple = TripleSet()
extend_triple.read_triples('../../datasets/FB15k/freebase_mtr100_mte100-test.txt')
# Out:
# * set up index for 961 relations, 12297 head entities, and 11825 tail entities

# %%
from learning import Learning
learner = Learning(dataset)
# Out:
# * indexed 100000 triples
# * indexed 200000 triples
# * indexed 300000 triples
# * indexed 400000 triples
# * set up index for 1345 relations, 14834 head entities, and 14903 tail entities

# %%
len(extend_triple.triples)
# Out:
# 59071

# %%
for triple in extend_triple.triples:
    learner.train_with_edge(triple)
# Out:
#  of previously rule = 70 num of all batch rules = 82
# =====> stored rules: 12
# created snapshot 12 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 38 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.5844155844155844 num of new rule = 32 num of previously rule = 45 num of all batch rules = 77
# =====> stored rules: 32
# created snapshot 32 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 40 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.5454545454545454 num of new rule = 35 num of previously rule = 42 num of all batch rules = 77
# =====> stored rules: 35
# created snapshot 35 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 58 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9224137931034483 num of new rule = 9 num of previously rule = 107 num of all batch rules = 116
# =====> stored rules: 9
# created snapshot 9 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 42 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9761904761904762 num of new rule = 2 num of previously rule = 82 num of all batch rules = 84
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 47 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8723404255319149 num of new rule = 12 num of previously rule = 82 num of all batch rules = 94
# =====> stored rules: 12
# created snapshot 12 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 51 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9801980198019802 num of new rule = 2 num of previously rule = 99 num of all batch rules = 101
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 48 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.711340206185567 num of new rule = 28 num of previously rule = 69 num of all batch rules = 97
# =====> stored rules: 28
# created snapshot 28 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 46 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9770114942528736 num of new rule = 2 num of previously rule = 85 num of all batch rules = 87
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 48 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9263157894736842 num of new rule = 7 num of previously rule = 88 num of all batch rules = 95
# =====> stored rules: 7
# created snapshot 7 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 52 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9587628865979382 num of new rule = 4 num of previously rule = 93 num of all batch rules = 97
# =====> stored rules: 4
# created snapshot 4 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 49 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 1.0 num of new rule = 0 num of previously rule = 96 num of all batch rules = 96
# =====> stored rules: 0
# =========================================================
# =====> increasing rule size of ACYCLIC rule to 2
# created snapshot 0 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 37 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.6756756756756757 num of new rule = 24 num of previously rule = 50 num of all batch rules = 74
# =====> stored rules: 24
# created snapshot 24 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 38 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8648648648648649 num of new rule = 10 num of previously rule = 64 num of all batch rules = 74
# =====> stored rules: 10
# created snapshot 10 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 31 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8387096774193549 num of new rule = 10 num of previously rule = 52 num of all batch rules = 62
# =====> stored rules: 10
# created snapshot 10 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 41 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 1.0 num of new rule = 0 num of previously rule = 83 num of all batch rules = 83
# =====> stored rules: 0
# =========================================================
# =====> increasing rule size of ACYCLIC rule to 2
# created snapshot 0 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 40 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9382716049382716 num of new rule = 5 num of previously rule = 76 num of all batch rules = 81
# =====> stored rules: 5
# created snapshot 5 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 48 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 1.0 num of new rule = 0 num of previously rule = 92 num of all batch rules = 92
# =====> stored rules: 0
# =========================================================
# =====> increasing rule size of ACYCLIC rule to 2
# created snapshot 0 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 50 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.97 num of new rule = 3 num of previously rule = 97 num of all batch rules = 100
# =====> stored rules: 3
# created snapshot 3 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 47 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.7722772277227723 num of new rule = 23 num of previously rule = 78 num of all batch rules = 101
# =====> stored rules: 23
# created snapshot 23 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 50 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9387755102040817 num of new rule = 6 num of previously rule = 92 num of all batch rules = 98
# =====> stored rules: 6
# created snapshot 6 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 46 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.956989247311828 num of new rule = 4 num of previously rule = 89 num of all batch rules = 93
# =====> stored rules: 4
# created snapshot 4 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 45 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.6888888888888889 num of new rule = 28 num of previously rule = 62 num of all batch rules = 90
# =====> stored rules: 28
# created snapshot 28 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 53 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 1.0 num of new rule = 0 num of previously rule = 102 num of all batch rules = 102
# =====> stored rules: 0
# =========================================================
# =====> increasing rule size of ACYCLIC rule to 2
# created snapshot 0 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 57 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9824561403508771 num of new rule = 2 num of previously rule = 112 num of all batch rules = 114
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 59 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.4672131147540984 num of new rule = 65 num of previously rule = 57 num of all batch rules = 122
# =====> stored rules: 65
# created snapshot 65 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 50 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.673469387755102 num of new rule = 32 num of previously rule = 66 num of all batch rules = 98
# =====> stored rules: 32
# created snapshot 32 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 48 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9895833333333334 num of new rule = 1 num of previously rule = 95 num of all batch rules = 96
# =====> stored rules: 1
# created snapshot 1 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 46 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9777777777777777 num of new rule = 2 num of previously rule = 88 num of all batch rules = 90
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 53 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.660377358490566 num of new rule = 36 num of previously rule = 70 num of all batch rules = 106
# =====> stored rules: 36
# created snapshot 36 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 40 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.6329113924050633 num of new rule = 29 num of previously rule = 50 num of all batch rules = 79
# =====> stored rules: 29
# created snapshot 29 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 44 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.5730337078651685 num of new rule = 38 num of previously rule = 51 num of all batch rules = 89
# =====> stored rules: 38
# created snapshot 38 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 51 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.95 num of new rule = 5 num of previously rule = 95 num of all batch rules = 100
# =====> stored rules: 5
# created snapshot 5 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 55 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 1.0 num of new rule = 0 num of previously rule = 106 num of all batch rules = 106
# =====> stored rules: 0
# =========================================================
# =====> increasing rule size of ACYCLIC rule to 2
# created snapshot 0 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 60 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.7355371900826446 num of new rule = 32 num of previously rule = 89 num of all batch rules = 121
# =====> stored rules: 32
# created snapshot 32 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 53 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8598130841121495 num of new rule = 15 num of previously rule = 92 num of all batch rules = 107
# =====> stored rules: 15
# created snapshot 15 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 53 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8962264150943396 num of new rule = 11 num of previously rule = 95 num of all batch rules = 106
# =====> stored rules: 11
# created snapshot 11 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 48 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8645833333333334 num of new rule = 13 num of previously rule = 83 num of all batch rules = 96
# =====> stored rules: 13
# created snapshot 13 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 57 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.5871559633027523 num of new rule = 45 num of previously rule = 64 num of all batch rules = 109
# =====> stored rules: 45
# created snapshot 45 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 51 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9607843137254902 num of new rule = 4 num of previously rule = 98 num of all batch rules = 102
# =====> stored rules: 4
# created snapshot 4 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 47 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9468085106382979 num of new rule = 5 num of previously rule = 89 num of all batch rules = 94
# =====> stored rules: 5
# created snapshot 5 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 41 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.975609756097561 num of new rule = 2 num of previously rule = 80 num of all batch rules = 82
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 45 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8181818181818182 num of new rule = 16 num of previously rule = 72 num of all batch rules = 88
# =====> stored rules: 16
# created snapshot 16 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 45 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8681318681318682 num of new rule = 12 num of previously rule = 79 num of all batch rules = 91
# =====> stored rules: 12
# created snapshot 12 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 54 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8990825688073395 num of new rule = 11 num of previously rule = 98 num of all batch rules = 109
# =====> stored rules: 11
# created snapshot 11 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 61 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.975609756097561 num of new rule = 3 num of previously rule = 120 num of all batch rules = 123
# =====> stored rules: 3
# created snapshot 3 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 51 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9411764705882353 num of new rule = 6 num of previously rule = 96 num of all batch rules = 102
# =====> stored rules: 6
# created snapshot 6 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 53 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9722222222222222 num of new rule = 3 num of previously rule = 105 num of all batch rules = 108
# =====> stored rules: 3
# created snapshot 3 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 56 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9910714285714286 num of new rule = 1 num of previously rule = 111 num of all batch rules = 112
# =====> stored rules: 1
# =========================================================
# =====> increasing rule size of ACYCLIC rule to 2
# created snapshot 1 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 51 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9705882352941176 num of new rule = 3 num of previously rule = 99 num of all batch rules = 102
# =====> stored rules: 3
# created snapshot 3 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 58 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9827586206896551 num of new rule = 2 num of previously rule = 114 num of all batch rules = 116
# =====> stored rules: 2
# created snapshot 2 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 62 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9512195121951219 num of new rule = 6 num of previously rule = 117 num of all batch rules = 123
# =====> stored rules: 6
# created snapshot 6 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 54 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.7410714285714286 num of new rule = 29 num of previously rule = 83 num of all batch rules = 112
# =====> stored rules: 29
# created snapshot 29 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 60 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.7327586206896551 num of new rule = 31 num of previously rule = 85 num of all batch rules = 116
# =====> stored rules: 31
# created snapshot 31 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 60 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.9652173913043478 num of new rule = 4 num of previously rule = 111 num of all batch rules = 115
# =====> stored rules: 4
# created snapshot 4 after 2 seconds
# *************************done learning*********************************
# =====> batch [ACYCLIC 1] 1 (sampled 1211975 pathes) *****
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-eb43230fbc34> in <module>
#       1 for triple in extend_triple.triples:
# ----> 2     learner.train_with_edge(triple)
#
# /study/KH2_2019-2020/thesis/source/AnyBURL/learning.py in train_with_edge(self, triple)
#     268         str_type = 'CYCLIC' if mine_cyclic_not_acyclic else 'ACYCLIC'
#     269         print('=====> batch [{} {}] {} (sampled {} pathes) *****'.format(str_type, rule_size + 1, batch_counter, path_counter))
# --> 270         current_coverage = batch_previously_found_rules / (batch_new_useful_rules + batch_previously_found_rules)
#     271         print('=====> fraction of previously seen rules within useful rules in this batch: {} num of new rule = {} num of previously rule = {} num of all batch rules = {}'.format(current_coverage,batch_new_useful_rules, batch_previously_found_rules, batch_rules))
#     272         print('=====> stored rules: {}'.format(len(useful_rules)))
#
# ZeroDivisionError: division by zero
